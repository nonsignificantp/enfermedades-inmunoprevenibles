# %% [markdown]
# #  Vaccination yearly records

# %% [markdown]
# The data shows absolute values of yearly doses of vaccines received by the population of Buenos Aires city during the years 1999 to 2016. The original data was taken from [Buenos Aires' Statistics and Census Bureau website](http://www.estadisticaciudad.gob.ar/eyc/?p=28782).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Copy-paste the data

# %% [markdown]
# All data below was directly copy-pasted from the excel available on the webpage.

# %%
year = "1999	2000	2001	2002	2003	2004	2005	2006	2007	2008	2009	2010	2011	2012	2013	2014	2015	2016".replace(',', '').split('\t')

# %%
antigripal = "15,243	26,408	16,618	27,971	41,347	31,652	46,664	41,268	57,582	67,107	113,293	543,153	376,968	304,273	478,904	361,321	499,004	566,673".replace(',', '').split('\t')
antihepatitis_A_peds = "-	-	-	-	-	-	-	-	-	-	-	-	-	70,404	30,705	50,209	39,685	72,993".replace(',', '').split('\t')
antihepatitis_B_peds = "-	-	-	-	-	-	-	-	-	-	-	-	-	90,920	41,393	42,761	81,106	101,291".replace(',', '').split('\t')
antihepatitis_A_adul = "2,355	3,173	2,600	6,971	24,012	19,047	41,912	55,310	55,304	48,025	35,065	37,960	49,795	4,046	4,611	6,127	340	7,413".replace(',', '').split('\t')
antihepatitis_B_adul = "12,096	45,127	126,360	243,858	270,874	310,727	249,095	225,344	226,823	225,519	127,198	102,431	135,648	28,246	50,177	72,046	81,281	106,908".replace(',', '').split('\t')
antimeningococo = "386	1,024	1,139	547	1,196	1,910	1,240	1,807	2,037	1,890	823	287	363	-	-	-	-	-".replace(',', '').split('\t')
antimeningococo_conjugada = "-	-	-	-	-	-	218	282	240	435	46	587	3,928	1,423	1,683	2,142	8,229	1,271".replace(',', '').split('\t')
antineumococo = "1,186	1,023	706	2,430	3,839	2,779	4,951	5,961	5,337	5,828	4,684	16,434	18,400	21,122	27,931	15,451	15,226	22,070".replace(',', '').split('\t')
antineumococo_conjugada = "-	-	-	-	-	-	234	686	1,139	965	172	1,586	9,761	191,980	77,997	140,382	97,685	174,100".replace(',', '').split('\t')
antiparotiditis = "35	4	2	212	35	-	-	-	-	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
antirrabica = "-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	17	28,831".replace(',', '').split('\t')
antirrubeolica = "57	112	92	104	1	-	-	-	-	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
antisarampionosa = "57,863	37,936	63,279	34,384	1,945	-	-	-	-	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
antitetanica = "118,694	34,361	16,362	11,561	12,544	1,869	1,848	-	-	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
antivaricela = "-	-	6	329	1,446	1,016	1,222	1,653	1,348	1,483	2,275	542	2,996	811	1,708	3,973	17,631	52,554".replace(',', '').split('\t')
bcg = "156,374	134,675	132,770	129,553	128,220	120,042	88,819	96,958	62,928	60,224	36,802	35,554	50,403	60,761	32,972	89,360	50,461	62,378".replace(',', '').split('\t')
antihepatitis_A_brote = "-	-	-	-	-	12,987	-	-	-	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
cuadruple_ambas = "151,337	153,396	118,798	174,583	175,605	171,527	154,396	148,593	149,684	136,301	71,601	29,249	35,052	35,893	17,020	11,501	1,997	3,031".replace(',', '').split('\t')
doble_adultos = "79,675	128,658	125,065	183,597	210,934	199,440	179,313	182,390	174,530	186,278	119,545	111,845	131,456	114,989	87,553	87,416	93,425	109,636".replace(',', '').split('\t')
doble_kids = "3,159	1,566	1,112	1,258	961	-	-	-	-	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
doble_viral = "-	-	20,261	92,886	35,160	25,781	68,117	694,965	22,671	157,006	40,945	21,079	10,022	14,882	15,707	112,077	24,236	6,141".replace(',', '').split('\t')
fiebre_amarilla = "-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	2,924".replace(',', '').split('\t')
fiebre_hemorragica_argentina = "-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	16	2,954".replace(',', '').split('\t')
igg_antitetanica = "-	-	-	-	-	-	-	2,837	1,631	1,814	1,165	186	229	483	72	-	-	-".replace(',', '').split('\t')
igg_antihepatitis_B = "-	-	-	-	-	21	77	77	186	148	73	48	187	188	52	129	75	712".replace(',', '').split('\t')
igg_inespecifica = "-	-	-	-	-	-	-	-	-	42	8	3	1	2	-	-	-	-".replace(',', '').split('\t')
igg_standart = "-	-	-	-	-	85	127	132	88	-	-	-	-	-	-	-	-	-".replace(',', '').split('\t')
antihaemophilus = "14,510	11,594	49,553	359	402	382	339	316	347	852	318	239	660	415	271	503	5,814	685".replace(',', '').split('\t')
pentavalente = "-	-	-	-	-	-	-	-	-	-	35,368	77,779	91,155	86,075	89,211	179,061	118,440	140,941".replace(',', '').split('\t')
ppd = "49,821	41,402	40,668	48,348	50,213	42,618	34,471	36,809	25,270	36,307	26,000	21,013	29,257	26,687	24,996	25,574	26,358	26,051".replace(',', '').split('\t')
quintuple_acelular = "-	-	-	163	-	910	2,193	2,866	2,930	2,792	2,159	703	2,765	1,387	802	1,844	1,752	-".replace(',', '').split('\t')
rotavirus = "-	-	-	-	-	-	-	-	52	1,396	3,670	1,130	5,054	2,348	2,667	4,710	55,365	105,924".replace(',', '').split('\t')
sabin = "239,228	175,847	236,262	251,975	239,632	225,325	201,626	190,106	183,751	181,387	160,627	145,419	164,004	166,363	136,223	243,444	158,098	157,185".replace(',', '').split('\t')
salk = "12	59,726	2,772	1,961	1,963	1,993	1,740	1,657	1,118	2,207	1,846	2,808	2,347	7,245	1,952	4,618	3,859	36,545".replace(',', '').split('\t')
sextuple = "-	348	-	11	-	-	-	-	-	-	-	-	-	-	217	782	1,875	766".replace(',', '').split('\t')
triple_acelular_niños = "79,333	65,007	100,030	53,318	55,396	49,681	44,071	40,131	35,313	33,186	26,883	24,352	29,784	33,967	24,087	41,630	33,954	46,436".replace(',', '').split('\t')
triple_acelular_adulto = "-	-	-	-	-	-	-	-	-	-	-	-	33,343	90,948	35,810	77,257	57,350	101,426".replace(',', '').split('\t')
triple_viral = "101,481	105,471	82,393	35,161	135,532	132,374	190,497	113,290	101,862	90,757	68,498	113,553	88,197	106,986	57,247	89,341	79,663	128,950".replace(',', '').split('\t')
tetraxim = "-	-	-	-	-	-	-	-	-	-	-	-	-	-	-	4,051	-	-".replace(',', '').split('\t')
vph = "-	-	-	-	-	-	-	-	-	-	-	-	16,359	64,134	35,034	63,178	41,409	51,161".replace(',', '').split('\t')
otras = "-	-	-	-	-	9,268	17,714	6,337	4,225	4,538	1,164	3,565	1,203	4,302	350	-	-	-".replace(',', '').split('\t')

# %% [markdown]
# ### To dataframe

# %% [markdown]
# Creates and saves a pandas dataframe.

# %%
vaccination_records = pd.DataFrame({'year':year,'antigripal':antigripal,'antihepatitis_A_peds':antihepatitis_A_peds,'antihepatitis_B_peds':antihepatitis_B_peds,
                         'antihepatitis_A_adul':antihepatitis_A_adul,'antihepatitis_B_adul':antihepatitis_B_adul,'antimeningococo':antimeningococo,'antimeningococo_conjugada':antimeningococo_conjugada,
                         'antineumococo':antineumococo,'antineumococo_conjugada':antineumococo_conjugada,'antiparotiditis':antiparotiditis,'antirrabica':antirrabica,
                         'antirrubeolica':antirrubeolica,'antisarampionosa':antisarampionosa,'antitetanica':antitetanica,'antivaricela':antivaricela,
                         'bcg':bcg,'antihepatitis_A_brote':antihepatitis_A_brote,'cuadruple_ambas':cuadruple_ambas,'doble_adultos':doble_adultos,
                         'doble_kids':doble_kids,'doble_viral':doble_viral,'fiebre_amarilla':fiebre_amarilla,'fiebre_hemorragica_argentina':fiebre_hemorragica_argentina,
                         'igg_antitetanica':igg_antitetanica,'igg_antihepatitis_B':igg_antihepatitis_B,'igg_standart':igg_standart,'igg_inespecifica':igg_inespecifica,
                         'antihaemophilus':antihaemophilus,'pentavalente':pentavalente,'ppd':ppd,'quintuple_acelular':quintuple_acelular,
                         'rotavirus':rotavirus,'sabin':sabin,'salk':salk,'sextuple':sextuple,
                         'triple_acelular_niños':triple_acelular_niños,'triple_acelular_adulto':triple_acelular_adulto,'triple_viral':triple_viral,'tetraxim':tetraxim,
                         'vph':vph,'otras':otras})

# %%
vaccination_records = vaccination_records.replace('-', '0')
vaccination_records = vaccination_records.astype(int)

# %%
vaccination_records.head()
# Out:
#    year  antigripal  antihepatitis_A_peds  antihepatitis_B_peds  \
# 0  1999       15243                     0                     0
# 1  2000       26408                     0                     0
# 2  2001       16618                     0                     0
# 3  2002       27971                     0                     0
# 4  2003       41347                     0                     0
#
#    antihepatitis_A_adul  antihepatitis_B_adul  antimeningococo  \
# 0                  2355                 12096              386
# 1                  3173                 45127             1024
# 2                  2600                126360             1139
# 3                  6971                243858              547
# 4                 24012                270874             1196
#
#    antimeningococo_conjugada  antineumococo  antineumococo_conjugada  ...    \
# 0                          0           1186                        0  ...
# ...

# %%
vaccination_records.to_csv('../datasets/vaccination-records.csv', index=False)

# %%
vaccination_records.set_index('year', drop=True).plot(figsize=(14.5,5), legend=False)
